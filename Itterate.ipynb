# %%
from Main import *

# %% [markdown]
# <b>Design Wingbox here<b>

# %%
t1 = t(1, 1)
t2 = t(2, 2)
t3 = t(3, 3)
t4 = t(4, 4)
t5 = t(5, 5)
stringer1 = Stringer(50, 0.2, b2)
stringer2 = Stringer(50, 0.3, b2)
stringer3 = Stringer(50, 0.4, b2)

# %%
wingbox_itteration_1 = WingBox(0.15, t3, 0.6, t3, t5, t5, middle_spar_x=0.37, middle_spar_t=t3, ribs=[0, 1, 2, 3, 5, b2], middle_spar_span=4, stringers=[stringer1, stringer2, stringer3])
wingbox_itteration_3 = WingBox(0.15, t3, 0.6, t3, t5, t5, middle_spar_x=0.37, middle_spar_t=t3, ribs=[0, 1, 2, 3, 5, b2], middle_spar_span=b2, stringers=[stringer1, stringer2, stringer3])
wingbox_itteration_2 = WingBox(0.2, t3, 0.6, t3, t5, t5)

# %%
wingbox_itteration_1 = WingBox(0.15, t3, 0.6, t3, t5, t5, middle_spar_x=0.37, middle_spar_t=t3, ribs=[0, 1, 2, 3, 5, b2], middle_spar_span=5)
wingbox_itteration_3 = WingBox(0.15, t3, 0.6, t3, t5, t5, middle_spar_x=0.37, middle_spar_t=t3, ribs=[0, 1, 2, 3, 5, b2], middle_spar_span=b2)

# %%
plt.plot(y, T_distribution(CL_crit, q_crit, wingbox_itteration_1)(y))

# %%
wingbox_itteration_1.plot_max_shear()

# %%
wingbox_itteration_1.tau_max(0, lambda y:-1.4e5)
# Out:
# 0.001132319880241563
# 287933445.9040087
# (385465588.2631084, 287432181.6343553, 190902567.81456232)

# %%
V(0)
# Out:
# 14770.993996310688

# %%
plt.plot(y, theta(y, wingbox_itteration_3, CL=CL_crit))

# %%
# T = T_distribution(CL_crit, q_crit, wingbox_itteration_1)(y)
T = -1
q1, q2, dtdx = wingbox_itteration_1.solve_shearflow(y, T)
# plt.plot(y, wingbox_itteration_2.J(y))
# plt.plot(y, 1/G/dtdx)
plt.plot(y, q1)
plt.plot(y, q2)

# %%
plt.plot(y, wingbox_itteration_1.J(y))

# %%
wingbox_itteration_1.enclosed_A(0, 0.2, 0.6)
# Out:
# 0.19663398890779418

# %%
wingbox_itteration_1.check_skin_buckling()
# Out:
# Ribs at 0 and 1 m span
# section between 0.15 and 0.37
# Sigma crit = 2.5e+07
# Sigma 1 max = -3.3e+08
# Sigma 2 max = -2.8e+08
# section between 0.37 and 0.6
# Sigma crit = 2.3e+07
# Sigma 1 max = -3.4e+08
# Sigma 2 max = -2.9e+08
# Ribs at 1 and 2 m span
# section between 0.15 and 0.37
# Sigma crit = 2.9e+07
# Sigma 1 max = -2.8e+08
# Sigma 2 max = -2.3e+08
# section between 0.37 and 0.6
# Sigma crit = 2.7e+07
# Sigma 1 max = -2.9e+08
# Sigma 2 max = -2.3e+08
# Ribs at 2 and 3 m span
# section between 0.15 and 0.37
# Sigma crit = 3.4e+07
# Sigma 1 max = -2.3e+08
# Sigma 2 max = -1.7e+08
# section between 0.37 and 0.6
# Sigma crit = 3.1e+07
# Sigma 1 max = -2.3e+08
# Sigma 2 max = -1.8e+08
# Ribs at 3 and 5 m span
# section between 0.15 and 0.37
# Sigma crit = 5e+07
# Sigma 1 max = -1.7e+08
# Sigma 2 max = -8e+07
# section between 0.37 and 0.6
# Sigma crit = 4.6e+07
# Sigma 1 max = -1.8e+08
# Sigma 2 max = -8.2e+07
# Ribs at 5 and 8.035 m span
# section between 0.15 and 0.37
# Sigma crit = 1.1e+08
# Sigma 1 max = -8e+07
# Sigma 2 max = -2.4
# section between 0.37 and 0.6
# Sigma crit = 9.7e+07
# Sigma 1 max = -8.2e+07
# Sigma 2 max = -2.5

# %%
wingbox_itteration_1.check_skin_buckling()
# Out:
# Ribs at 0 and 1 m span
# section between 0.15 and 0.2
# Sigma crit = 4.8e+08
# Sigma 1 max = -3.2e+08
# Sigma 2 max = -2.7e+08
# section between 0.2 and 0.3
# Sigma crit = 1.2e+08
# Sigma 1 max = -3.5e+08
# Sigma 2 max = -2.9e+08
# section between 0.3 and 0.37
# Sigma crit = 2.5e+08
# Sigma 1 max = -4e+08
# Sigma 2 max = -3.4e+08
# section between 0.37 and 0.4
# Sigma crit = 1.3e+09
# Sigma 1 max = -4.2e+08
# Sigma 2 max = -3.6e+08
# section between 0.4 and 0.6
# Sigma crit = 3e+07
# Sigma 1 max = -3.3e+08
# Sigma 2 max = -2.8e+08
# Ribs at 1 and 2 m span
# section between 0.15 and 0.2
# Sigma crit = 5.6e+08
# Sigma 1 max = -2.7e+08
# Sigma 2 max = -2.2e+08
# section between 0.2 and 0.3
# Sigma crit = 1.4e+08
# Sigma 1 max = -2.9e+08
# Sigma 2 max = -2.4e+08
# section between 0.3 and 0.37
# Sigma crit = 2.9e+08
# Sigma 1 max = -3.4e+08
# Sigma 2 max = -2.7e+08
# section between 0.37 and 0.4
# Sigma crit = 1.6e+09
# Sigma 1 max = -3.6e+08
# Sigma 2 max = -2.9e+08
# section between 0.4 and 0.6
# Sigma crit = 3.5e+07
# Sigma 1 max = -2.8e+08
# Sigma 2 max = -2.3e+08
# Ribs at 2 and 3 m span
# section between 0.15 and 0.2
# Sigma crit = 6.6e+08
# Sigma 1 max = -2.2e+08
# Sigma 2 max = -1.7e+08
# section between 0.2 and 0.3
# Sigma crit = 1.7e+08
# Sigma 1 max = -2.4e+08
# Sigma 2 max = -1.8e+08
# section between 0.3 and 0.37
# Sigma crit = 3.4e+08
# Sigma 1 max = -2.7e+08
# Sigma 2 max = -2.1e+08
# section between 0.37 and 0.4
# Sigma crit = 1.8e+09
# Sigma 1 max = -2.9e+08
# Sigma 2 max = -2.2e+08
# section between 0.4 and 0.6
# Sigma crit = 4.1e+07
# Sigma 1 max = -2.3e+08
# Sigma 2 max = -1.7e+08
# Ribs at 3 and 5 m span
# section between 0.15 and 0.2
# Sigma crit = 9.7e+08
# Sigma 1 max = -1.7e+08
# Sigma 2 max = -7.7e+07
# section between 0.2 and 0.3
# Sigma crit = 2.4e+08
# Sigma 1 max = -1.8e+08
# Sigma 2 max = -8.3e+07
# section between 0.3 and 0.37
# Sigma crit = 4.9e+08
# Sigma 1 max = -2.1e+08
# Sigma 2 max = -9.6e+07
# section between 0.37 and 0.4
# Sigma crit = 2.7e+09
# Sigma 1 max = -2.2e+08
# Sigma 2 max = -1e+08
# section between 0.4 and 0.6
# Sigma crit = 6e+07
# Sigma 1 max = -1.7e+08
# Sigma 2 max = -7.9e+07
# Ribs at 5 and 8.035 m span
# section between 0.15 and 0.2
# Sigma crit = 2.1e+09
# Sigma 1 max = -7.7e+07
# Sigma 2 max = -2.3
# section between 0.2 and 0.3
# Sigma crit = 5.1e+08
# Sigma 1 max = -8.3e+07
# Sigma 2 max = -2.5
# section between 0.3 and 0.37
# Sigma crit = 1e+09
# Sigma 1 max = -9.6e+07
# Sigma 2 max = -2.9
# section between 0.37 and 0.4
# Sigma crit = 5.7e+09
# Sigma 1 max = -1e+08
# Sigma 2 max = -3.0
# section between 0.4 and 0.6
# Sigma crit = 1.3e+08
# Sigma 1 max = -7.9e+07
# Sigma 2 max = -2.4

# %%
system = np.array([[40/200, -10/200, -1], [-10/100, /100, -1], [200, 50, 0]])
righthandside = np.array([0, 0, 1])
q1, q2, dtdx = LA.solve(system, righthandside)
q1, q2, dtdx
# Out:
# (0.004, 0.003999999999999999, 0.0006)

# %%
LA.solve(system, righthandside*100)
# Out:
# array([0.4 , 0.4 , 0.06])

# %%
system
# Out:
# array([[ 2.e-01, -5.e-02, -1.e+00],
#        [-1.e-01,  3.e-01, -1.e+00],
#        [ 2.e+02,  1.e+02,  0.e+00]])

# %%
righthandside * T
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3580/1299857637.py in <module>
# ----> 1 righthandside * T
#
# ValueError: operands could not be broadcast together with shapes (3,) (800,)

# %%
def t_stacked(y):
    if y < 2:
        return 8
